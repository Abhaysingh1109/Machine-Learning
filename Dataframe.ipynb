# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Creating a DataFrame

# %%
data = {
    'Name':['John','Ana','Peter','Linda'],
    'Age': [28,34,29,42],
    'City': ['New York','Paris',"Berlin",'London'],
    'Salary': [65000,70000,62000,85000]
    
}
df = pd.DataFrame(data)

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1    Ana   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
data_list = [
    ["Alice", 20, 85],
    ["Bob", 21, 90],
    ["Charlie", 19, 78],
    ["David", 22, 88]
]
df2 = pd.DataFrame(data_list)
columns = ['Name','Age','City','Salary']
df2 = pd.DataFrame(data_list,columns)

# %%
df2
# Out:
#               0   1   2
# Name      Alice  20  85
# Age         Bob  21  90
# City    Charlie  19  78
# Salary    David  22  88

# %% [markdown]
# Selection and Indexing of Columns

# %%
df2
# Out:
#               0   1   2
# Name      Alice  20  85
# Age         Bob  21  90
# City    Charlie  19  78
# Salary    David  22  88

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1    Ana   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df[['Name','Age']]
# Out:
#     Name  Age
# 0   John   28
# 1    Ana   34
# 2  Peter   29
# 3  Linda   42

# %% [markdown]
# Creating New Columns

# %%
df['Designation'] = ['Doctor','Engineer','Pilot','Teacher']

# %%
df
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000      Doctor
# 1    Ana   34     Paris   70000    Engineer
# 2  Peter   29    Berlin   62000       Pilot
# 3  Linda   42    London   85000     Teacher

# %% [markdown]
# Remove column

# %%
df.drop('Designation',axis=1,inplace=True)

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1    Ana   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df.loc[1]
# Out:
# Name        Ana
# Age          34
# City      Paris
# Salary    70000
# Name: 1, dtype: object

# %% [markdown]
# Selecting subset of Rows and columm

# %%
df.loc[[0,1]][['City','Salary']]
# Out:
#        City  Salary
# 0  New York   65000
# 1     Paris   70000

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1    Ana   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df.loc[[2,3]][['Name','Age']]
# Out:
#     Name  Age
# 2  Peter   29
# 3  Linda   42

# %% [markdown]
# Conditional Selection

# %%
# I want to see who's age is above 30

# %%
df[df['Age'] > 30]
# Out:
#     Name  Age    City  Salary
# 1    Ana   34   Paris   70000
# 3  Linda   42  London   85000

# %%
df[(df['Age']> 30) & (df['City']== "Paris")]
# Out:
#   Name  Age   City  Salary
# 1  Ana   34  Paris   70000
